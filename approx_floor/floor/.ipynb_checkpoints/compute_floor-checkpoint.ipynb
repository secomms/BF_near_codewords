# %%
reset()

t = 80
r = 2003
v = 11
seed = 0
#dec_type = "max"
dec_type = "max"

file_name = "FLOOR_"+str(t)+"_"+str(r)+"_"+str(v)+"_"+str(seed)+"_"+dec_type+".txt"

f = open(file_name)
vals_str = f.read()
dfr_vals = []
lines =  vals_str.split("\n")
for i in range(len(lines)-1):
    a = lines[i].split()
    dfr_vals.append([int(a[0]), float(a[1]), float(a[2])])

# %%
dfr_std = 0
for val in dfr_vals:
    u = val[0]
    eps = val[1]
    pr = N(binomial(v,u)*binomial(2*r-v, t-u)/binomial(2*r,t))
    term = (1-(1-pr)^(2*r))*eps
    dfr_std += term
    print("- u = ",u,", eps = ","{:e}".format(eps),"---> DFR contribution = ","{:e}".format(term))
print(" ")
print("DFR STD = ","{:e}".format(dfr_std))
# Out:
# - u =  2 , eps =  0.000000e+00 ---> DFR contribution =  0e-15
# - u =  3 , eps =  0.000000e+00 ---> DFR contribution =  0e-15
# - u =  4 , eps =  1.220000e-04 ---> DFR contribution =  1.91359515326301e-5
# - u =  5 , eps =  1.750000e-02 ---> DFR contribution =  8.08520726937223e-5
# - u =  6 , eps =  4.380000e-01 ---> DFR contribution =  3.87951417180890e-5
# - u =  7 , eps =  9.770000e-01 ---> DFR contribution =  1.16630698597486e-6
# - u =  8 , eps =  9.990000e-01 ---> DFR contribution =  1.10957682112334e-8
# - u =  9 , eps =  1.000000e+00 ---> DFR contribution =  6.80475675807202e-11
# - u =  10 , eps =  1.000000e+00 ---> DFR contribution =  4.44755343664838e-13
# - u =  11 , eps =  1.000000e+00 ---> DFR contribution =  0e-15
#
# DFR STD =  1.39960637190950e-4

# %%
dfr_improved = 0
for val in dfr_vals:
    u = val[0]
    eps = val[2]
    pr = N(binomial(v,u)*binomial(2*r-v, t-u)/binomial(2*r,t))
    term = (1-(1-pr)^(2*r))*eps
    dfr_improved += term
    print("- u = ",u,", eps = ","{:e}".format(eps),"---> DFR contribution = ","{:e}".format(term))
print(" ")
print("DFR IMPROVED = ","{:e}".format(dfr_improved))
# Out:
# - u =  2 , eps =  0.000000e+00 ---> DFR contribution =  0e-15
# - u =  3 , eps =  0.000000e+00 ---> DFR contribution =  0e-15
# - u =  4 , eps =  0.000000e+00 ---> DFR contribution =  0e-15
# - u =  5 , eps =  1.550000e-04 ---> DFR contribution =  7.16118358144398e-7
# - u =  6 , eps =  4.840000e-05 ---> DFR contribution =  4.28695173323175e-9
# - u =  7 , eps =  1.680000e-04 ---> DFR contribution =  2.00552275991583e-10
# - u =  8 , eps =  9.030000e-05 ---> DFR contribution =  1.00295082029467e-12
# - u =  9 , eps =  6.960000e-05 ---> DFR contribution =  4.73611070361812e-15
# - u =  10 , eps =  3.870000e-05 ---> DFR contribution =  1.72120317998292e-17
# - u =  11 , eps =  4.990000e-05 ---> DFR contribution =  0e-15
#
# DFR IMPROVED =  7.20606869857764e-7
